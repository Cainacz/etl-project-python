# %%
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(project_root)

# %%
from src.analysis import run_analysis_query

# %%
monthly = run_analysis_query("monthly_trend.sql")
display(monthly)

# %%
payment_methods = run_analysis_query("payment_method")
display(payment_methods)

# %%
product_by_gender = run_analysis_query("product_by_gender")
display(product_by_gender)

# %%
revenue_by_city = run_analysis_query("revenue_by_city")
display(revenue_by_city)

# %%
revenue_by_customer_type = run_analysis_query("revenue_by_customer_type")
display(revenue_by_customer_type)

# %%
revenue_by_hour = run_analysis_query("revenue_by_hour")
display(revenue_by_hour)

# %%
revenue_by_products = run_analysis_query("revenue_by_product")
display(revenue_by_products)
